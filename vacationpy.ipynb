# %%
#VacationPy

#Google Places API for this part of the assignment.

#myGoogleAPI = 'AIzaSyAJ6cFrQmG5IC15P-iWuMPiKfvOZiABx_I'

#jupyter-gmaps

import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import gmaps
import json

# %%
# %run ./api_keys.ipynb

# %%
cities = pd.read_csv('python-api-challenge/citydata.csv')

# %%
cities
# Out:
#      Unnamed: 0      lat       lon       name country  temp_max  temp_min  \
# 0             0  42.0970  -79.2353  Jamestown      US     61.00     59.00
# 1             1  55.7435  -97.8558   Thompson      CA     32.00     32.00
# 2             2 -54.8000  -68.3000    Ushuaia      AR     46.40     46.40
# 3             3 -34.5833  150.8552   Flinders      AU     66.00     66.00
# 4             4  42.6001  -73.9662     Albany      US     64.00     60.01
# ..          ...      ...       ...        ...     ...       ...       ...
# 546         546 -24.8500  152.3500  Bundaberg      AU     87.80     87.80
# 547         547 -10.1732   31.3694     Mungwi      ZM     59.90     59.90
# 548         548 -13.5927   24.2008    Kabompo      ZM     55.92     55.92
# 549         549  -4.4500   26.6667    Kasongo      CD     65.71     65.71
# 550         550  51.3223   42.7678    Kamenka      RU     37.00     37.00
#
#      clouds  visibility   wind  humidity
# ...

# %%
#Humidity heatmap

# %%
humidity = cities["humidity"]
locations = cities[["lat", "lon"]]

# %%
humidity.dtypes
# Out:
# dtype('int64')

# %%
fig = gmaps.figure()

# %%
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
vacay_city = cities.loc[(cities["temp_max"] > 70)]

# %%
vacay_city
# Out:
#      Unnamed: 0      lat       lon            name country  temp_max  \
# 6             6 -23.1203 -134.9692         Rikitea      PF     78.57
# 13           13  22.0752 -159.3190           Kapaa      US     75.20
# 16           16 -21.3585   55.7679  Saint-Philippe      RE     78.80
# 20           20 -10.6167  150.6667         Samarai      PG     83.32
# 23           23  15.2833  -23.7667        Tarrafal      CV     71.60
# ..          ...      ...       ...             ...     ...       ...
# 534         534  -3.3333  128.9167          Amahai      ID     85.60
# 535         535  -8.5785   13.6643          Caxito      AO     75.20
# 542         542  30.9000   75.8500        Ludhiana      IN     91.00
# 544         544  14.3122  121.1114      Santa Rosa      PH     89.60
# 546         546 -24.8500  152.3500       Bundaberg      AU     87.80
#
#      temp_min  clouds  visibility   wind  humidity
# 6       78.57      14       10000  12.12        75
# ...

# %%
vacay_city = vacay_city.loc[(cities["temp_max"] < 80)]

# %%
vacay_city
# Out:
#      Unnamed: 0      lat       lon            name country  temp_max  \
# 6             6 -23.1203 -134.9692         Rikitea      PF     78.57
# 13           13  22.0752 -159.3190           Kapaa      US     75.20
# 16           16 -21.3585   55.7679  Saint-Philippe      RE     78.80
# 23           23  15.2833  -23.7667        Tarrafal      CV     71.60
# 54           54  19.7297 -155.0900            Hilo      US     75.20
# ..          ...      ...       ...             ...     ...       ...
# 509         509 -23.3500   47.6000    Vangaindrano      MG     71.92
# 514         514 -32.0350  -52.0986      Rio Grande      BR     73.00
# 520         520  31.7667 -107.6167  Puerto Palomas      MX     71.60
# 525         525  -1.5746    9.2618          Omboué      GA     76.91
# 535         535  -8.5785   13.6643          Caxito      AO     75.20
#
#      temp_min  clouds  visibility   wind  humidity
# 6       78.57      14       10000  12.12        75
# ...

# %%
vacay_city = vacay_city.loc[(cities["clouds"] == 0)]

# %%
vacay_city
# Out:
#      Unnamed: 0      lat       lon                   name country  temp_max  \
# 16           16 -21.3585   55.7679         Saint-Philippe      RE     78.80
# 23           23  15.2833  -23.7667               Tarrafal      CV     71.60
# 108         108  16.8634  -99.8901     Acapulco de Juárez      MX     77.04
# 117         117  27.0167 -100.5167    Lampazos de Naranjo      MX     75.49
# 120         120 -22.1160   14.2845            Henties Bay     NaN     75.99
# 125         125 -21.6403  -41.0511      São João da Barra      BR     70.36
# 135         135 -26.6481   15.1594               Lüderitz     NaN     72.59
# 170         170 -22.9575   14.5053             Walvis Bay     NaN     75.99
# 174         174 -20.3297  -40.2925             Vila Velha      BR     73.99
# 185         185 -22.9661  -42.0278        Arraial do Cabo      BR     74.48
# 254         254 -25.2406  130.9889                 Yulara      AU     73.40
# ...

# %%
vacay_city = vacay_city.loc[(cities["wind"] < 10)]

# %%
vacay_city
# Out:
#      Unnamed: 0      lat       lon                   name country  temp_max  \
# 16           16 -21.3585   55.7679         Saint-Philippe      RE     78.80
# 108         108  16.8634  -99.8901     Acapulco de Juárez      MX     77.04
# 117         117  27.0167 -100.5167    Lampazos de Naranjo      MX     75.49
# 120         120 -22.1160   14.2845            Henties Bay     NaN     75.99
# 125         125 -21.6403  -41.0511      São João da Barra      BR     70.36
# 135         135 -26.6481   15.1594               Lüderitz     NaN     72.59
# 170         170 -22.9575   14.5053             Walvis Bay     NaN     75.99
# 174         174 -20.3297  -40.2925             Vila Velha      BR     73.99
# 261         261  17.9333  -94.0833            Las Choapas      MX     77.95
# 272         272  -8.2578  -49.2647  Conceição do Araguaia      BR     77.00
# 317         317 -28.4478   21.2561               Upington      ZA     71.60
# ...

# %%
vacay_city.reset_index(inplace=True)
del vacay_city['index']

# %%
vacay_city
# Out:
#     Unnamed: 0      lat       lon                   name country  temp_max  \
# 0           16 -21.3585   55.7679         Saint-Philippe      RE     78.80
# 1          108  16.8634  -99.8901     Acapulco de Juárez      MX     77.04
# 2          117  27.0167 -100.5167    Lampazos de Naranjo      MX     75.49
# 3          125 -21.6403  -41.0511      São João da Barra      BR     70.36
# 4          174 -20.3297  -40.2925             Vila Velha      BR     73.99
# 5          261  17.9333  -94.0833            Las Choapas      MX     77.95
# 6          272  -8.2578  -49.2647  Conceição do Araguaia      BR     77.00
# 7          317 -28.4478   21.2561               Upington      ZA     71.60
# 8          405 -21.1500   55.2833              Saint-Leu      RE     78.80
# 9          423 -35.1667  173.1667                Ahipara      NZ     71.69
# 10         500 -21.3393   55.4781           Saint-Pierre      RE     78.80
# ...

# %%
vacay_city.drop('Unnamed: 0',
  axis='columns', inplace=True)
# Out:
# /Users/christinemagnotta/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
vacay_city
# Out:
#         lat       lon                   name country  temp_max  temp_min  \
# 0  -21.3585   55.7679         Saint-Philippe      RE     78.80     73.40
# 1   16.8634  -99.8901     Acapulco de Juárez      MX     77.04     77.04
# 2   27.0167 -100.5167    Lampazos de Naranjo      MX     75.49     75.49
# 3  -21.6403  -41.0511      São João da Barra      BR     70.36     70.36
# 4  -20.3297  -40.2925             Vila Velha      BR     73.99     66.20
# 5   17.9333  -94.0833            Las Choapas      MX     77.95     77.95
# 6   -8.2578  -49.2647  Conceição do Araguaia      BR     77.00     77.00
# 7  -28.4478   21.2561               Upington      ZA     71.60     71.60
# 8  -21.1500   55.2833              Saint-Leu      RE     78.80     73.40
# 9  -35.1667  173.1667                Ahipara      NZ     71.69     71.69
# 10 -21.3393   55.4781           Saint-Pierre      RE     78.80     75.99
# 11  36.2083 -115.9839                Pahrump      US     73.00     70.00
#
# ...

# %%
hotellist = []

for i in range(len(vacay_city)):
    lat = vacay_city.loc[i]['lat']
    lon = vacay_city.loc[i]['lon']

    params = {
        "location": f"{lat},{lon}",
        "radius": 5000,
        "types" : "hotel",
        "key": gkeys
    }
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    requested = requests.get(base_url, params=params)
    jsn = requested.json()
    try:
        hotellist.append(jsn['results'][0]['name'])
    except:
        hotellist.append("")
vacay_city["Hotel Name"] = hotellist
vacay_city = vacay_city.dropna(how='any')
# Out:
# <ipython-input-66-c013cf77bf2d>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vacay_city["Hotel Name"] = hotellist

# %%
vacay_city
# Out:
#         lat       lon                   name country  temp_max  temp_min  \
# 0  -21.3585   55.7679         Saint-Philippe      RE     78.80     73.40
# 1   16.8634  -99.8901     Acapulco de Juárez      MX     77.04     77.04
# 2   27.0167 -100.5167    Lampazos de Naranjo      MX     75.49     75.49
# 3  -21.6403  -41.0511      São João da Barra      BR     70.36     70.36
# 4  -20.3297  -40.2925             Vila Velha      BR     73.99     66.20
# 5   17.9333  -94.0833            Las Choapas      MX     77.95     77.95
# 6   -8.2578  -49.2647  Conceição do Araguaia      BR     77.00     77.00
# 7  -28.4478   21.2561               Upington      ZA     71.60     71.60
# 8  -21.1500   55.2833              Saint-Leu      RE     78.80     73.40
# 9  -35.1667  173.1667                Ahipara      NZ     71.69     71.69
# 10 -21.3393   55.4781           Saint-Pierre      RE     78.80     75.99
# 11  36.2083 -115.9839                Pahrump      US     73.00     70.00
#
# ...
